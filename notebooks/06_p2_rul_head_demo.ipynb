# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# P2 RUL Head Demo\n",
        "\n",
        "Fits a hazard model from score-derived covariates and computes RUL quantiles."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "import numpy as np\n",
        "\n",
        "from ssp.p2_prognose.hazard import HazardModel, HazardSpec\n",
        "from ssp.p2_prognose.rul import rul_quantiles\n",
        "\n",
        "rng = np.random.default_rng(0)\n",
        "z = rng.normal(size=5000).astype(np.float64)\n",
        "dt = np.full_like(z, 0.01)\n",
        "failure_like = (z > 2.5)\n",
        "\n",
        "haz = HazardModel(HazardSpec())\n",
        "haz.fit(z=z, dt_s=dt, failure=failure_like)\n",
        "\n",
        "q = rul_quantiles(haz, z=z[:10], p=np.asarray([0.1, 0.5, 0.9], dtype=np.float64))\n",
        "print(q.q_s)\n"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python",
      "version": "3.11"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
