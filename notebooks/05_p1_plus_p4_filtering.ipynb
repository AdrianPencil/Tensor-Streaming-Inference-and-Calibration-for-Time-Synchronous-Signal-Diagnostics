# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# P1 + P4 Filtering\n",
        "\n",
        "Runs the full workflow (P4->P1->P2->P3) and prints summary stats."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "import numpy as np\n",
        "\n",
        "from ssp.core.config import SyntheticConfig\n",
        "from ssp.datasets.synthetic import generate_synthetic\n",
        "from ssp.p1_detect.pipeline import P1Spec\n",
        "from ssp.workflows.pipelines import WorkflowSpec, run_workflow\n",
        "\n",
        "cfg = SyntheticConfig(seed=5, n_sensors=8, n_steps=20000, dt_s=0.01, anomaly_rate=0.002)\n",
        "ds = generate_synthetic(cfg)\n",
        "\n",
        "wf = WorkflowSpec(p1=P1Spec())\n",
        "out = run_workflow(ds.t_event_s, ds.y, ds.sensor_id, ds.is_anomaly, wf)\n",
        "\n",
        "p1 = out['p1']\n",
        "print('alerts:', int(np.sum(p1['alert'])))\n",
        "print('rul_q shape:', out['p2']['rul_q_s'].shape)\n",
        "print('forecast len:', len(out['p3']['forecast']))\n"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python",
      "version": "3.11"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
