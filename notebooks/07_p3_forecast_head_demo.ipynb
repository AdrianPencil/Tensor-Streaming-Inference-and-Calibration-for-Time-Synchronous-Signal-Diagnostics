# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# P3 Forecast Head Demo\n",
        "\n",
        "Runs a seasonal-naive baseline forecast."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "import numpy as np\n",
        "\n",
        "from ssp.p3_forecast.model import ForecastSpec, forecast_baseline\n",
        "\n",
        "y = np.sin(np.linspace(0, 20 * np.pi, 240)).astype(np.float64)\n",
        "spec = ForecastSpec(horizon=48, season=24)\n",
        "y_hat = forecast_baseline(y, spec)\n",
        "print(y_hat[:10])\n"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python",
      "version": "3.11"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
