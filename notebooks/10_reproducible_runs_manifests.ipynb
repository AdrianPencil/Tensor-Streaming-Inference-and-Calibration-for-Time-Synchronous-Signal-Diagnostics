# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# Reproducible Runs + Manifests\n",
        "\n",
        "Runs the orchestrator entrypoint logic (programmatic version) and inspects metadata.\n"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "from pathlib import Path\n",
        "import json\n",
        "\n",
        "from ssp.workflows.orchestration import RunSpec, run_one\n",
        "\n",
        "out_dir = Path('runs/notebook_demo')\n",
        "out_dir.mkdir(parents=True, exist_ok=True)\n",
        "\n",
        "spec = RunSpec(\n",
        "    config_path=Path('experiments/p1_synth_early_warning.yaml'),\n",
        "    out_dir=out_dir,\n",
        "    repo_root=Path('.'),\n",
        ")\n",
        "\n",
        "root = run_one(spec)\n",
        "md = json.loads((root / 'metadata.json').read_text())\n",
        "print(md)\n"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python",
      "version": "3.11"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
