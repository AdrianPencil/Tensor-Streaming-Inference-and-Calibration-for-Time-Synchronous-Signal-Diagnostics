# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# Noise Spectroscopy + System ID\n",
        "\n",
        "Computes a Welch PSD and fits a simple parametric model."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "import numpy as np\n",
        "\n",
        "from ssp.noise_spectroscopy.psd import PsdSpec, welch_psd\n",
        "from ssp.noise_spectroscopy.fit import fit_one_f\n",
        "\n",
        "rng = np.random.default_rng(0)\n",
        "fs = 10000.0\n",
        "n = 262144\n",
        "x = rng.normal(scale=1.0, size=n).astype(np.float64)\n",
        "\n",
        "f, p = welch_psd(x, PsdSpec(fs_hz=fs, nperseg=2048))\n",
        "res = fit_one_f(f, p)\n",
        "print(res)\n"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python",
      "version": "3.11"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
